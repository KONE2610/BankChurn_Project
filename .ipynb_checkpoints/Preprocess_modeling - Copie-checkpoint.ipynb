# %% [markdown]
# ## Les différentes étapes du preprocessing
# 1. Diviser le dataset en trainset et testset
# 2. Traiter les valeurs manquantes s'il y en a
# 3. Faire de la feature engineering si possible (Créer des variables nouvelles à partir des variables existantes)
# 4. Traiter les valeurs aberrantes s'il yen a (optionnel)
# 5. Traiter les labels rares s'il y en a
# 6. Faire l'encodage des variables nominales
# 7. Faire d'autres tansformations (normalisation, transformer les données en distributions normales)
#
# N.B: Il est conseiller de faire chacune de ces étapes en créant des fonctions. Cela permet d'essayer plusieurs idées.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('BankChurners.csv')
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                  39                         5                       1
# 1                  44                         6                       1
# 2                  36                         4                       1
# 3                  34                         3                       4
# 4                  21                         5                       1
# ...               ...                       ...                     ...
# 10122              40                         3                       2
# 10123              25                         4                       2
# 10124              36                         5                       3
# 10125              36                         4                       3
# 10126              25                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                          3       12691.0                  777
# 1                          2        8256.0                  864
# 2                          0        3418.0                    0
# 3                          1        3313.0                 2517
# 4                          0        4716.0                    0
# ...                      ...           ...                  ...
# 10122                      3        4003.0                 1851
# 10123                      3        4277.0                 2186
# 10124                      4        5409.0                    0
# 10125                      3        5281.0                    0
# 10126                      4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
# [10127 rows x 23 columns]

# %%
data_1 = data.iloc[:,1:21]
data_1.head(5)
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000

# %%
df = data_1.copy()

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size = 0.2, random_state = 0)

# %%
trainset["Attrition_Flag"].value_counts()
# Out:
# Existing Customer    6783
# Attrited Customer    1318
# Name: Attrition_Flag, dtype: int64

# %%
testset["Attrition_Flag"].value_counts()
# Out:
# Existing Customer    1717
# Attrited Customer     309
# Name: Attrition_Flag, dtype: int64

# %%
var_cat = [i for i in df.columns if df[i].dtypes == 'O']
var_cat
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %% [markdown]
# Nous allons ici essayer de combiner certains labels dans la variable Card_Category. La raison est que dans l'EDA,
# nous avons vu qu'il y avait 0% de carte Platinum et Gold moins de 2%. Les combiner permettrait de reduire le bruit dans
# notre dataset mais de réduire le nombre de variables quand on va faire du one hot encoding sur nos variables catégorielles

# %%
def find_frequent_labels(df, var, rare_perc):
    
    # function finds the labels that are shared by more than
    # a certain % of the passengers in the dataset
    
    df = df.copy()
    
    tmp = df.groupby(var)[var].count() / len(df)
    
    return tmp[tmp > rare_perc].index


for var in var_cat:
    
    # find the frequent categories
    frequent_ls = find_frequent_labels(trainset, var, 0.02)
    
    # replace rare categories by the string "Rare"
    trainset[var] = np.where(trainset[var].isin(
        frequent_ls), trainset[var], 'Rare')
    
    testset[var] = np.where(testset[var].isin(
        frequent_ls), testset[var], 'Rare')

# %%
testset['Card_Category'].value_counts()
# Out:
# Blue      1883
# Silver     113
# Rare        30
# Name: Card_Category, dtype: int64

# %%
trainset['Card_Category'].value_counts()
# Out:
# Blue      7553
# Silver     442
# Rare       106
# Name: Card_Category, dtype: int64

# %%
## On voit que le label platinum dans la feature Card_Category a été supprimée car il a moins 1% d'occurence

# %%
#X_train = trainset.drop('Attrition_Flag', axis = 1)
#y_train = trainset['Attrition_Flag']
#X_test = testset.drop('Attrition_Flag', axis = 1)
#y_test = testset['Attrition_Flag']

# %% [markdown]
# ## Encodage des variables catégorielles

# %%
def encodage(df):
    code = {'Existing Customer':0,
            'Attrited Customer':1,
            'M':0,
            'F':1
            }
    
    df = df.map(code)
        
    return df

# %%
y_train = encodage(y_train)
y_test = encodage(y_test)
X_train['Gender'] = encodage(X_train['Gender'])
X_test['Gender'] = encodage ( X_test['Gender'])

# %%
y_test.value_counts()
# Out:
# 0    1717
# 1     309
# Name: Attrition_Flag, dtype: int64

# %%
vars_cat = ['Education_Level','Marital_Status','Income_Category','Card_Category']

for var in vars_cat:
    
    
    X_train = pd.concat([X_train,
                         pd.get_dummies(X_train[var], prefix=var, drop_first=True)
                         ], axis=1)
    
    X_test = pd.concat([X_test,
                        pd.get_dummies(X_test[var], prefix=var, drop_first=True)
                        ], axis=1)
    

X_train.drop(labels=vars_cat, axis=1, inplace=True)
X_test.drop(labels=vars_cat, axis=1, inplace=True)

X_train.shape, X_test.shape
# Out:
# ((8101, 31), (2026, 31))

# %%
X_test
# Out:
#       Customer_Age  Gender  Dependent_count  Months_on_book  \
# 3358            44       0                5              39
# 9951            44       1                3              34
# 3848            37       1                3              26
# 1666            34       0                1              36
# 8383            51       1                4              33
# ...            ...     ...              ...             ...
# 9982            31       1                1              18
# 2872            37       1                3              25
# 4424            52       1                2              43
# 7470            42       1                3              36
# 9651            39       0                1              29
#
#       Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 3358                         5                       2                      0
# 9951                         2                       3                      3
# 3848                         3                       1                      2
# 1666                         6                       2                      3
# 8383                         2                       4                      3
# ...                        ...                     ...                    ...
# 9982                         3                       1                      3
# 2872                         3                       2                      4
# 4424                         3                       2                      4
# 7470                         4                       2                      2
# 9651                         3                       1                      2
#
#       Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 3358       16034.0                 1597          14437.0
# 9951       26021.0                    0          26021.0
# 3848        2917.0                 2216            701.0
# 1666        3735.0                 1285           2450.0
# 8383        3068.0                 2071            997.0
# ...            ...                  ...              ...
# 9982        3399.0                 1800           1599.0
# 2872        2282.0                    0           2282.0
# 4424        1822.0                 1605            217.0
# 7470        2526.0                 2048            478.0
# 9651        9680.0                 2101           7579.0
#
#       Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 3358                 0.775             3628              59
# 9951                 1.040             8898              60
# 3848                 0.810             4524              67
# 1666                 1.034             1877              33
# 8383                 0.854             5524              71
# ...                    ...              ...             ...
# 9982                 0.752            13148             121
# 2872                 0.741             2751              68
# 4424                 0.756             2538              39
# 7470                 0.716             4267              72
# 9651                 0.626            15152             100
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Education_Level_Doctorate  \
# 3358                0.903                  0.100                          0
# 9951                0.538                  0.000                          0
# 3848                0.489                  0.760                          0
# 1666                1.200                  0.344                          0
# 8383                0.972                  0.675                          0
# ...                   ...                    ...                        ...
# 9982                0.806                  0.530                          0
# 2872                0.659                  0.000                          0
# 4424                0.696                  0.881                          1
# 7470                0.800                  0.811                          0
# 9651                0.695                  0.217                          0
#
#       Education_Level_Graduate  Education_Level_High School  \
# 3358                         0                            0
# 9951                         0                            0
# 3848                         0                            1
# 1666                         1                            0
# 8383                         0                            1
# ...                        ...                          ...
# 9982                         0                            0
# 2872                         0                            1
# 4424                         0                            0
# 7470                         1                            0
# 9651                         0                            1
#
#       Education_Level_Post-Graduate  Education_Level_Uneducated  \
# 3358                              0                           1
# 9951                              0                           0
# 3848                              0                           0
# 1666                              0                           0
# 8383                              0                           0
# ...                             ...                         ...
# 9982                              0                           0
# 2872                              0                           0
# 4424                              0                           0
# 7470                              0                           0
# 9651                              0                           0
#
#       Education_Level_Unknown  Marital_Status_Married  Marital_Status_Single  \
# 3358                        0                       0                      0
# 9951                        1                       0                      1
# 3848                        0                       0                      1
# 1666                        0                       1                      0
# 8383                        0                       0                      1
# ...                       ...                     ...                    ...
# 9982                        1                       0                      1
# 2872                        0                       0                      1
# 4424                        0                       1                      0
# 7470                        0                       1                      0
# 9651                        0                       0                      1
#
#       Marital_Status_Unknown  Income_Category_$40K - $60K  \
# 3358                       0                            0
# 9951                       0                            0
# 3848                       0                            0
# 1666                       0                            1
# 8383                       0                            0
# ...                      ...                          ...
# 9982                       0                            0
# 2872                       0                            0
# 4424                       0                            1
# 7470                       0                            0
# 9651                       0                            0
#
#       Income_Category_$60K - $80K  Income_Category_$80K - $120K  \
# 3358                            1                             0
# 9951                            0                             0
# 3848                            0                             0
# 1666                            0                             0
# 8383                            0                             0
# ...                           ...                           ...
# 9982                            0                             0
# 2872                            0                             0
# 4424                            0                             0
# 7470                            0                             0
# 9651                            0                             1
#
#       Income_Category_Less than $40K  Income_Category_Unknown  \
# 3358                               0                        0
# 9951                               0                        1
# 3848                               1                        0
# 1666                               0                        0
# 8383                               1                        0
# ...                              ...                      ...
# 9982                               1                        0
# 2872                               1                        0
# 4424                               0                        0
# 7470                               1                        0
# 9651                               0                        0
#
#       Card_Category_Rare  Card_Category_Silver
# 3358                   0                     0
# 9951                   0                     0
# 3848                   0                     0
# 1666                   0                     0
# 8383                   0                     0
# ...                  ...                   ...
# 9982                   0                     0
# 2872                   0                     0
# 4424                   0                     0
# 7470                   0                     0
# 9651                   0                     0
#
# [2026 rows x 31 columns]

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
# create scaler
#scaler = StandardScaler()

#  fit  the scaler to the train set
#scaler.fit(X_train) 

# transform the train and test set
#X_train = scaler.transform(X_train)

#X_test = scaler.transform(X_test)

# %%
model = make_pipeline(StandardScaler(),LogisticRegression(C=0.0005, random_state=0))

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.0005, random_state=0))])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
class_ = model.predict(X_train)
pred = model.predict_proba(X_train)[:,1]

# determine mse and rmse
print('train roc-auc: {}'.format(roc_auc_score(y_train, pred)))
print('train accuracy: {}'.format(accuracy_score(y_train, class_)))
print()

# make predictions for test set
class_ = model.predict(X_test)
pred = model.predict_proba(X_test)[:,1]
print(confusion_matrix(y_test, class_))
print(classification_report(y_test, class_))

# determine mse and rmse
print('test roc-auc: {}'.format(roc_auc_score(y_test, pred)))
print('test accuracy: {}'.format(accuracy_score(y_test, class_)))
print()
# Out:
# train roc-auc: 0.8881872851368803
# train accuracy: 0.844957412665103
#
# [[1717    0]
#  [ 296   13]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1717
#            1       1.00      0.04      0.08       309
#
#     accuracy                           0.85      2026
#    macro avg       0.93      0.52      0.50      2026
# weighted avg       0.88      0.85      0.79      2026
#
# test roc-auc: 0.881274820800184
# test accuracy: 0.8538993089832182

# %%
class_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV

# %%
LR =  LogisticRegression()
LRparam_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
    'max_iter': list(range(100,800,100)),
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}
LR_search = GridSearchCV(LR, param_grid=LRparam_grid, refit = True, verbose = 3, cv=5)

# fitting the model for grid search 
LR_search.fit(X_train , y_train)
LR_search.best_params_
# summarize
print('Mean Accuracy: %.3f' % LR_search.best_score_)
print('Config: %s' % LR_search.best_params_)
# Out:
# Fitting 5 folds for each of 490 candidates, totalling 2450 fits
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.5s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.3s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 2/5] END .C=0.001, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 3/5] END .C=0.001, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 4/5] END .C=0.001, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 5/5] END .C=0.001, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.7s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.6s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.7s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.7s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 2/5] END ..C=0.001, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 3/5] END ..C=0.001, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 4/5] END ..C=0.001, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 5/5] END ..C=0.001, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 1/5] END .C=0.001, max_iter=100, penalty=l2, solver=saga; total time=   0.3s
# [CV 2/5] END .C=0.001, max_iter=100, penalty=l2, solver=saga; total time=   0.3s
# [CV 3/5] END .C=0.001, max_iter=100, penalty=l2, solver=saga; total time=   0.3s
# [CV 4/5] END .C=0.001, max_iter=100, penalty=l2, solver=saga; total time=   0.3s
# [CV 5/5] END .C=0.001, max_iter=100, penalty=l2, solver=saga; total time=   0.3s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=200, penalty=l1, solver=saga; total time=   0.7s
# [CV 2/5] END .C=0.001, max_iter=200, penalty=l1, solver=saga; total time=   0.7s
# [CV 3/5] END .C=0.001, max_iter=200, penalty=l1, solver=saga; total time=   0.7s
# [CV 4/5] END .C=0.001, max_iter=200, penalty=l1, solver=saga; total time=   0.7s
# [CV 5/5] END .C=0.001, max_iter=200, penalty=l1, solver=saga; total time=   0.7s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=200, penalty=l2, solver=sag; total time=   0.5s
# [CV 2/5] END ..C=0.001, max_iter=200, penalty=l2, solver=sag; total time=   0.5s
# [CV 3/5] END ..C=0.001, max_iter=200, penalty=l2, solver=sag; total time=   0.5s
# [CV 4/5] END ..C=0.001, max_iter=200, penalty=l2, solver=sag; total time=   0.5s
# [CV 5/5] END ..C=0.001, max_iter=200, penalty=l2, solver=sag; total time=   0.5s
# [CV 1/5] END .C=0.001, max_iter=200, penalty=l2, solver=saga; total time=   0.6s
# [CV 2/5] END .C=0.001, max_iter=200, penalty=l2, solver=saga; total time=   0.6s
# [CV 3/5] END .C=0.001, max_iter=200, penalty=l2, solver=saga; total time=   0.5s
# [CV 4/5] END .C=0.001, max_iter=200, penalty=l2, solver=saga; total time=   0.5s
# [CV 5/5] END .C=0.001, max_iter=200, penalty=l2, solver=saga; total time=   0.5s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear; total time=   0.4s
# [CV 1/5] END ..C=0.001, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=300, penalty=l1, solver=saga; total time=   1.0s
# [CV 2/5] END .C=0.001, max_iter=300, penalty=l1, solver=saga; total time=   1.0s
# [CV 3/5] END .C=0.001, max_iter=300, penalty=l1, solver=saga; total time=   1.0s
# [CV 4/5] END .C=0.001, max_iter=300, penalty=l1, solver=saga; total time=   1.0s
# [CV 5/5] END .C=0.001, max_iter=300, penalty=l1, solver=saga; total time=   1.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=300, penalty=l2, solver=sag; total time=   0.8s
# [CV 2/5] END ..C=0.001, max_iter=300, penalty=l2, solver=sag; total time=   0.8s
# [CV 3/5] END ..C=0.001, max_iter=300, penalty=l2, solver=sag; total time=   0.8s
# [CV 4/5] END ..C=0.001, max_iter=300, penalty=l2, solver=sag; total time=   0.8s
# [CV 5/5] END ..C=0.001, max_iter=300, penalty=l2, solver=sag; total time=   0.7s
# [CV 1/5] END .C=0.001, max_iter=300, penalty=l2, solver=saga; total time=   0.8s
# [CV 2/5] END .C=0.001, max_iter=300, penalty=l2, solver=saga; total time=   0.9s
# [CV 3/5] END .C=0.001, max_iter=300, penalty=l2, solver=saga; total time=   0.9s
# [CV 4/5] END .C=0.001, max_iter=300, penalty=l2, solver=saga; total time=   0.9s
# [CV 5/5] END .C=0.001, max_iter=300, penalty=l2, solver=saga; total time=   0.9s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear; total time=   0.3s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear; total time=   1.2s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=400, penalty=l1, solver=saga; total time=   1.4s
# [CV 2/5] END .C=0.001, max_iter=400, penalty=l1, solver=saga; total time=   1.4s
# [CV 3/5] END .C=0.001, max_iter=400, penalty=l1, solver=saga; total time=   1.6s
# [CV 4/5] END .C=0.001, max_iter=400, penalty=l1, solver=saga; total time=   1.7s
# [CV 5/5] END .C=0.001, max_iter=400, penalty=l1, solver=saga; total time=   1.5s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.3s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.3s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=400, penalty=l2, solver=sag; total time=   1.1s
# [CV 2/5] END ..C=0.001, max_iter=400, penalty=l2, solver=sag; total time=   1.0s
# [CV 3/5] END ..C=0.001, max_iter=400, penalty=l2, solver=sag; total time=   1.0s
# [CV 4/5] END ..C=0.001, max_iter=400, penalty=l2, solver=sag; total time=   1.1s
# [CV 5/5] END ..C=0.001, max_iter=400, penalty=l2, solver=sag; total time=   1.1s
# [CV 1/5] END .C=0.001, max_iter=400, penalty=l2, solver=saga; total time=   1.2s
# [CV 2/5] END .C=0.001, max_iter=400, penalty=l2, solver=saga; total time=   1.2s
# [CV 3/5] END .C=0.001, max_iter=400, penalty=l2, solver=saga; total time=   1.2s
# [CV 4/5] END .C=0.001, max_iter=400, penalty=l2, solver=saga; total time=   1.1s
# [CV 5/5] END .C=0.001, max_iter=400, penalty=l2, solver=saga; total time=   1.1s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear; total time=   0.3s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear; total time=   0.2s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=500, penalty=l1, solver=saga; total time=   1.9s
# [CV 2/5] END .C=0.001, max_iter=500, penalty=l1, solver=saga; total time=   1.9s
# [CV 3/5] END .C=0.001, max_iter=500, penalty=l1, solver=saga; total time=   1.9s
# [CV 4/5] END .C=0.001, max_iter=500, penalty=l1, solver=saga; total time=   1.9s
# [CV 5/5] END .C=0.001, max_iter=500, penalty=l1, solver=saga; total time=   1.8s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=500, penalty=l2, solver=sag; total time=   1.3s
# [CV 2/5] END ..C=0.001, max_iter=500, penalty=l2, solver=sag; total time=   1.3s
# [CV 3/5] END ..C=0.001, max_iter=500, penalty=l2, solver=sag; total time=   1.3s
# [CV 4/5] END ..C=0.001, max_iter=500, penalty=l2, solver=sag; total time=   1.3s
# [CV 5/5] END ..C=0.001, max_iter=500, penalty=l2, solver=sag; total time=   1.5s
# [CV 1/5] END .C=0.001, max_iter=500, penalty=l2, solver=saga; total time=   1.5s
# [CV 2/5] END .C=0.001, max_iter=500, penalty=l2, solver=saga; total time=   1.4s
# [CV 3/5] END .C=0.001, max_iter=500, penalty=l2, solver=saga; total time=   1.4s
# [CV 4/5] END .C=0.001, max_iter=500, penalty=l2, solver=saga; total time=   1.4s
# [CV 5/5] END .C=0.001, max_iter=500, penalty=l2, solver=saga; total time=   1.5s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear; total time=   0.2s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear; total time=   0.9s
# [CV 1/5] END ..C=0.001, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=600, penalty=l1, solver=saga; total time=   2.2s
# [CV 2/5] END .C=0.001, max_iter=600, penalty=l1, solver=saga; total time=   2.0s
# [CV 3/5] END .C=0.001, max_iter=600, penalty=l1, solver=saga; total time=   1.9s
# [CV 4/5] END .C=0.001, max_iter=600, penalty=l1, solver=saga; total time=   1.9s
# [CV 5/5] END .C=0.001, max_iter=600, penalty=l1, solver=saga; total time=   1.9s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 2/5] END ..C=0.001, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 3/5] END ..C=0.001, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 4/5] END ..C=0.001, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 5/5] END ..C=0.001, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 1/5] END .C=0.001, max_iter=600, penalty=l2, solver=saga; total time=   1.5s
# [CV 2/5] END .C=0.001, max_iter=600, penalty=l2, solver=saga; total time=   1.5s
# [CV 3/5] END .C=0.001, max_iter=600, penalty=l2, solver=saga; total time=   1.5s
# [CV 4/5] END .C=0.001, max_iter=600, penalty=l2, solver=saga; total time=   1.5s
# [CV 5/5] END .C=0.001, max_iter=600, penalty=l2, solver=saga; total time=   1.5s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear; total time=   0.4s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear; total time=   0.3s
# [CV 1/5] END ..C=0.001, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ..C=0.001, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ..C=0.001, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ..C=0.001, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ..C=0.001, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END .C=0.001, max_iter=700, penalty=l1, solver=saga; total time=   2.2s
# [CV 2/5] END .C=0.001, max_iter=700, penalty=l1, solver=saga; total time=   2.2s
# [CV 3/5] END .C=0.001, max_iter=700, penalty=l1, solver=saga; total time=   2.2s
# [CV 4/5] END .C=0.001, max_iter=700, penalty=l1, solver=saga; total time=   2.1s
# [CV 5/5] END .C=0.001, max_iter=700, penalty=l1, solver=saga; total time=   2.2s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ..C=0.001, max_iter=700, penalty=l2, solver=sag; total time=   1.6s
# [CV 2/5] END ..C=0.001, max_iter=700, penalty=l2, solver=sag; total time=   1.6s
# [CV 3/5] END ..C=0.001, max_iter=700, penalty=l2, solver=sag; total time=   1.7s
# [CV 4/5] END ..C=0.001, max_iter=700, penalty=l2, solver=sag; total time=   1.6s
# [CV 5/5] END ..C=0.001, max_iter=700, penalty=l2, solver=sag; total time=   1.6s
# [CV 1/5] END .C=0.001, max_iter=700, penalty=l2, solver=saga; total time=   1.7s
# [CV 2/5] END .C=0.001, max_iter=700, penalty=l2, solver=saga; total time=   1.8s
# [CV 3/5] END .C=0.001, max_iter=700, penalty=l2, solver=saga; total time=   1.7s
# [CV 4/5] END .C=0.001, max_iter=700, penalty=l2, solver=saga; total time=   1.8s
# [CV 5/5] END .C=0.001, max_iter=700, penalty=l2, solver=saga; total time=   1.8s
# [CV 1/5] END C=0.01, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=0.01, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=0.01, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=0.01, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=0.01, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=0.01, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=0.01, max_iter=100, penalty=l1, solver=saga; total time=   0.3s
# [CV 2/5] END ..C=0.01, max_iter=100, penalty=l1, solver=saga; total time=   0.2s
# [CV 3/5] END ..C=0.01, max_iter=100, penalty=l1, solver=saga; total time=   0.2s
# [CV 4/5] END ..C=0.01, max_iter=100, penalty=l1, solver=saga; total time=   0.2s
# [CV 5/5] END ..C=0.01, max_iter=100, penalty=l1, solver=saga; total time=   0.2s
# [CV 1/5] END C=0.01, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.6s
# [CV 2/5] END C=0.01, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV 3/5] END C=0.01, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.6s
# [CV 4/5] END C=0.01, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV 5/5] END C=0.01, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV 1/5] END .C=0.01, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 2/5] END ...C=0.01, max_iter=100, penalty=l2, solver=sag; total time=   0.1s
# [CV 3/5] END ...C=0.01, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 4/5] END ...C=0.01, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 5/5] END ...C=0.01, max_iter=100, penalty=l2, solver=sag; total time=   0.2s
# [CV 1/5] END ..C=0.01, max_iter=100, penalty=l2, solver=saga; total time=   0.2s
# [CV 2/5] END ..C=0.01, max_iter=100, penalty=l2, solver=saga; total time=   0.2s
# [CV 3/5] END ..C=0.01, max_iter=100, penalty=l2, solver=saga; total time=   0.2s
# [CV 4/5] END ..C=0.01, max_iter=100, penalty=l2, solver=saga; total time=   0.2s
# [CV 5/5] END ..C=0.01, max_iter=100, penalty=l2, solver=saga; total time=   0.2s
# [CV 1/5] END C=0.01, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=200, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=0.01, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=200, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=0.01, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=0.01, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=0.01, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=0.01, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=0.01, max_iter=200, penalty=l1, solver=saga; total time=   0.6s
# [CV 2/5] END ..C=0.01, max_iter=200, penalty=l1, solver=saga; total time=   0.6s
# [CV 3/5] END ..C=0.01, max_iter=200, penalty=l1, solver=saga; total time=   0.6s
# [CV 4/5] END ..C=0.01, max_iter=200, penalty=l1, solver=saga; total time=   0.6s
# [CV 5/5] END ..C=0.01, max_iter=200, penalty=l1, solver=saga; total time=   0.6s
# [CV 1/5] END C=0.01, max_iter=200, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 2/5] END C=0.01, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 3/5] END C=0.01, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 4/5] END C=0.01, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.01, max_iter=200, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 1/5] END .C=0.01, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END .C=0.01, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 5/5] END .C=0.01, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=200, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=200, penalty=l2, solver=sag; total time=   0.4s
# [CV 2/5] END ...C=0.01, max_iter=200, penalty=l2, solver=sag; total time=   0.4s
# [CV 3/5] END ...C=0.01, max_iter=200, penalty=l2, solver=sag; total time=   0.4s
# [CV 4/5] END ...C=0.01, max_iter=200, penalty=l2, solver=sag; total time=   0.4s
# [CV 5/5] END ...C=0.01, max_iter=200, penalty=l2, solver=sag; total time=   0.4s
# [CV 1/5] END ..C=0.01, max_iter=200, penalty=l2, solver=saga; total time=   0.4s
# [CV 2/5] END ..C=0.01, max_iter=200, penalty=l2, solver=saga; total time=   0.4s
# [CV 3/5] END ..C=0.01, max_iter=200, penalty=l2, solver=saga; total time=   0.4s
# [CV 4/5] END ..C=0.01, max_iter=200, penalty=l2, solver=saga; total time=   0.5s
# [CV 5/5] END ..C=0.01, max_iter=200, penalty=l2, solver=saga; total time=   0.4s
# [CV 1/5] END C=0.01, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=300, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=0.01, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=300, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=0.01, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=0.01, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=0.01, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=0.01, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=0.01, max_iter=300, penalty=l1, solver=saga; total time=   0.9s
# [CV 2/5] END ..C=0.01, max_iter=300, penalty=l1, solver=saga; total time=   0.9s
# [CV 3/5] END ..C=0.01, max_iter=300, penalty=l1, solver=saga; total time=   0.9s
# [CV 4/5] END ..C=0.01, max_iter=300, penalty=l1, solver=saga; total time=   0.9s
# [CV 5/5] END ..C=0.01, max_iter=300, penalty=l1, solver=saga; total time=   0.9s
# [CV 1/5] END C=0.01, max_iter=300, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 2/5] END C=0.01, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 3/5] END C=0.01, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 4/5] END C=0.01, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.01, max_iter=300, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 1/5] END .C=0.01, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END .C=0.01, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 5/5] END .C=0.01, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=300, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=300, penalty=l2, solver=sag; total time=   0.7s
# [CV 2/5] END ...C=0.01, max_iter=300, penalty=l2, solver=sag; total time=   0.6s
# [CV 3/5] END ...C=0.01, max_iter=300, penalty=l2, solver=sag; total time=   0.6s
# [CV 4/5] END ...C=0.01, max_iter=300, penalty=l2, solver=sag; total time=   0.6s
# [CV 5/5] END ...C=0.01, max_iter=300, penalty=l2, solver=sag; total time=   0.6s
# [CV 1/5] END ..C=0.01, max_iter=300, penalty=l2, solver=saga; total time=   0.7s
# [CV 2/5] END ..C=0.01, max_iter=300, penalty=l2, solver=saga; total time=   0.7s
# [CV 3/5] END ..C=0.01, max_iter=300, penalty=l2, solver=saga; total time=   0.7s
# [CV 4/5] END ..C=0.01, max_iter=300, penalty=l2, solver=saga; total time=   0.7s
# [CV 5/5] END ..C=0.01, max_iter=300, penalty=l2, solver=saga; total time=   0.7s
# [CV 1/5] END C=0.01, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=400, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=0.01, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=0.01, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=0.01, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=0.01, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=0.01, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=0.01, max_iter=400, penalty=l1, solver=saga; total time=   1.3s
# [CV 2/5] END ..C=0.01, max_iter=400, penalty=l1, solver=saga; total time=   1.2s
# [CV 3/5] END ..C=0.01, max_iter=400, penalty=l1, solver=saga; total time=   1.2s
# [CV 4/5] END ..C=0.01, max_iter=400, penalty=l1, solver=saga; total time=   1.2s
# [CV 5/5] END ..C=0.01, max_iter=400, penalty=l1, solver=saga; total time=   1.3s
# [CV 1/5] END C=0.01, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 2/5] END C=0.01, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 3/5] END C=0.01, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 4/5] END C=0.01, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.01, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 1/5] END .C=0.01, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 3/5] END .C=0.01, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 5/5] END .C=0.01, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 2/5] END ...C=0.01, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 3/5] END ...C=0.01, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 4/5] END ...C=0.01, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 5/5] END ...C=0.01, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 1/5] END ..C=0.01, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 2/5] END ..C=0.01, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 3/5] END ..C=0.01, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 4/5] END ..C=0.01, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 5/5] END ..C=0.01, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 1/5] END C=0.01, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=0.01, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=0.01, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=0.01, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=0.01, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=0.01, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=0.01, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=0.01, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=0.01, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=0.01, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=0.01, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=0.01, max_iter=500, penalty=l1, solver=saga; total time=   1.6s
# [CV 2/5] END ..C=0.01, max_iter=500, penalty=l1, solver=saga; total time=   1.6s
# [CV 3/5] END ..C=0.01, max_iter=500, penalty=l1, solver=saga; total time=   1.5s
# [CV 4/5] END ..C=0.01, max_iter=500, penalty=l1, solver=saga; total time=   1.6s
# [CV 5/5] END ..C=0.01, max_iter=500, penalty=l1, solver=saga; total time=   1.6s
# [CV 1/5] END C=0.01, max_iter=500, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV 2/5] END C=0.01, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 3/5] END C=0.01, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV 4/5] END C=0.01, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV 5/5] END C=0.01, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.2s
# [CV 1/5] END .C=0.01, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.0s
# ...
# [CV 3/5] END .C=1000, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=1000, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=1000, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=400, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 5/5] END C=1000, max_iter=400, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=1000, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=1000, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=1000, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=1000, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=1000, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=1000, max_iter=400, penalty=l1, solver=saga; total time=   1.5s
# [CV 2/5] END ..C=1000, max_iter=400, penalty=l1, solver=saga; total time=   1.4s
# [CV 3/5] END ..C=1000, max_iter=400, penalty=l1, solver=saga; total time=   1.5s
# [CV 4/5] END ..C=1000, max_iter=400, penalty=l1, solver=saga; total time=   1.4s
# [CV 5/5] END ..C=1000, max_iter=400, penalty=l1, solver=saga; total time=   1.5s
# [CV 1/5] END C=1000, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 2/5] END C=1000, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 3/5] END C=1000, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 4/5] END C=1000, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 5/5] END C=1000, max_iter=400, penalty=l2, solver=newton-cg; total time=   1.6s
# [CV 1/5] END .C=1000, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.3s
# [CV 2/5] END .C=1000, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.3s
# [CV 3/5] END .C=1000, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 4/5] END .C=1000, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV 1/5] END C=1000, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=400, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=1000, max_iter=400, penalty=l2, solver=sag; total time=   1.0s
# [CV 2/5] END ...C=1000, max_iter=400, penalty=l2, solver=sag; total time=   1.0s
# [CV 3/5] END ...C=1000, max_iter=400, penalty=l2, solver=sag; total time=   1.0s
# [CV 4/5] END ...C=1000, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 5/5] END ...C=1000, max_iter=400, penalty=l2, solver=sag; total time=   0.9s
# [CV 1/5] END ..C=1000, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 2/5] END ..C=1000, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 3/5] END ..C=1000, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 4/5] END ..C=1000, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 5/5] END ..C=1000, max_iter=400, penalty=l2, solver=saga; total time=   1.0s
# [CV 1/5] END C=1000, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=1000, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=1000, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=1000, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=1000, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=1000, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 1/5] END ...C=1000, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=1000, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=1000, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=1000, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=1000, max_iter=500, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=1000, max_iter=500, penalty=l1, solver=saga; total time=   1.9s
# [CV 2/5] END ..C=1000, max_iter=500, penalty=l1, solver=saga; total time=   1.8s
# [CV 3/5] END ..C=1000, max_iter=500, penalty=l1, solver=saga; total time=   1.8s
# [CV 4/5] END ..C=1000, max_iter=500, penalty=l1, solver=saga; total time=   1.8s
# [CV 5/5] END ..C=1000, max_iter=500, penalty=l1, solver=saga; total time=   1.8s
# [CV 1/5] END C=1000, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 2/5] END C=1000, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 3/5] END C=1000, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 4/5] END C=1000, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 5/5] END C=1000, max_iter=500, penalty=l2, solver=newton-cg; total time=   1.6s
# [CV 1/5] END .C=1000, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.3s
# [CV 2/5] END .C=1000, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.4s
# [CV 3/5] END .C=1000, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 4/5] END .C=1000, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=500, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV 1/5] END C=1000, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=1000, max_iter=500, penalty=l2, solver=sag; total time=   1.2s
# [CV 2/5] END ...C=1000, max_iter=500, penalty=l2, solver=sag; total time=   1.2s
# [CV 3/5] END ...C=1000, max_iter=500, penalty=l2, solver=sag; total time=   1.2s
# [CV 4/5] END ...C=1000, max_iter=500, penalty=l2, solver=sag; total time=   1.2s
# [CV 5/5] END ...C=1000, max_iter=500, penalty=l2, solver=sag; total time=   1.2s
# [CV 1/5] END ..C=1000, max_iter=500, penalty=l2, solver=saga; total time=   1.3s
# [CV 2/5] END ..C=1000, max_iter=500, penalty=l2, solver=saga; total time=   1.3s
# [CV 3/5] END ..C=1000, max_iter=500, penalty=l2, solver=saga; total time=   1.3s
# [CV 4/5] END ..C=1000, max_iter=500, penalty=l2, solver=saga; total time=   1.3s
# [CV 5/5] END ..C=1000, max_iter=500, penalty=l2, solver=saga; total time=   1.3s
# [CV 1/5] END C=1000, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=600, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=1000, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=1000, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=1000, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=1000, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=600, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=1000, max_iter=600, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 2/5] END C=1000, max_iter=600, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=600, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=600, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=600, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 1/5] END ...C=1000, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=1000, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=1000, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=1000, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=1000, max_iter=600, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=1000, max_iter=600, penalty=l1, solver=saga; total time=   2.2s
# [CV 2/5] END ..C=1000, max_iter=600, penalty=l1, solver=saga; total time=   2.2s
# [CV 3/5] END ..C=1000, max_iter=600, penalty=l1, solver=saga; total time=   2.3s
# [CV 4/5] END ..C=1000, max_iter=600, penalty=l1, solver=saga; total time=   2.4s
# [CV 5/5] END ..C=1000, max_iter=600, penalty=l1, solver=saga; total time=   2.3s
# [CV 1/5] END C=1000, max_iter=600, penalty=l2, solver=newton-cg; total time=   1.6s
# [CV 2/5] END C=1000, max_iter=600, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 3/5] END C=1000, max_iter=600, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 4/5] END C=1000, max_iter=600, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 5/5] END C=1000, max_iter=600, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 1/5] END .C=1000, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.3s
# [CV 2/5] END .C=1000, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.5s
# [CV 3/5] END .C=1000, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 4/5] END .C=1000, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=600, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV 1/5] END C=1000, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=600, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=1000, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 2/5] END ...C=1000, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 3/5] END ...C=1000, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 4/5] END ...C=1000, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 5/5] END ...C=1000, max_iter=600, penalty=l2, solver=sag; total time=   1.4s
# [CV 1/5] END ..C=1000, max_iter=600, penalty=l2, solver=saga; total time=   1.6s
# [CV 2/5] END ..C=1000, max_iter=600, penalty=l2, solver=saga; total time=   1.6s
# [CV 3/5] END ..C=1000, max_iter=600, penalty=l2, solver=saga; total time=   1.6s
# [CV 4/5] END ..C=1000, max_iter=600, penalty=l2, solver=saga; total time=   1.6s
# [CV 5/5] END ..C=1000, max_iter=600, penalty=l2, solver=saga; total time=   1.7s
# [CV 1/5] END C=1000, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=700, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV 1/5] END .C=1000, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 2/5] END .C=1000, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 3/5] END .C=1000, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 4/5] END .C=1000, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=700, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV 1/5] END C=1000, max_iter=700, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=700, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 3/5] END C=1000, max_iter=700, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 4/5] END C=1000, max_iter=700, penalty=l1, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=700, penalty=l1, solver=liblinear; total time=   0.1s
# [CV 1/5] END ...C=1000, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 2/5] END ...C=1000, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 3/5] END ...C=1000, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 4/5] END ...C=1000, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 5/5] END ...C=1000, max_iter=700, penalty=l1, solver=sag; total time=   0.0s
# [CV 1/5] END ..C=1000, max_iter=700, penalty=l1, solver=saga; total time=   2.6s
# [CV 2/5] END ..C=1000, max_iter=700, penalty=l1, solver=saga; total time=   2.6s
# [CV 3/5] END ..C=1000, max_iter=700, penalty=l1, solver=saga; total time=   2.7s
# [CV 4/5] END ..C=1000, max_iter=700, penalty=l1, solver=saga; total time=   2.7s
# [CV 5/5] END ..C=1000, max_iter=700, penalty=l1, solver=saga; total time=   2.5s
# [CV 1/5] END C=1000, max_iter=700, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 2/5] END C=1000, max_iter=700, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 3/5] END C=1000, max_iter=700, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 4/5] END C=1000, max_iter=700, penalty=l2, solver=newton-cg; total time=   1.4s
# [CV 5/5] END C=1000, max_iter=700, penalty=l2, solver=newton-cg; total time=   1.5s
# [CV 1/5] END .C=1000, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.4s
# [CV 2/5] END .C=1000, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.6s
# [CV 3/5] END .C=1000, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV 4/5] END .C=1000, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV 5/5] END .C=1000, max_iter=700, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV 1/5] END C=1000, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 2/5] END C=1000, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 3/5] END C=1000, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 4/5] END C=1000, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 5/5] END C=1000, max_iter=700, penalty=l2, solver=liblinear; total time=   0.0s
# [CV 1/5] END ...C=1000, max_iter=700, penalty=l2, solver=sag; total time=   1.8s
# [CV 2/5] END ...C=1000, max_iter=700, penalty=l2, solver=sag; total time=   1.8s
# [CV 3/5] END ...C=1000, max_iter=700, penalty=l2, solver=sag; total time=   1.7s
# [CV 4/5] END ...C=1000, max_iter=700, penalty=l2, solver=sag; total time=   1.7s
# [CV 5/5] END ...C=1000, max_iter=700, penalty=l2, solver=sag; total time=   1.7s
# [CV 1/5] END ..C=1000, max_iter=700, penalty=l2, solver=saga; total time=   1.8s
# [CV 2/5] END ..C=1000, max_iter=700, penalty=l2, solver=saga; total time=   1.8s
# [CV 3/5] END ..C=1000, max_iter=700, penalty=l2, solver=saga; total time=   1.9s
# [CV 4/5] END ..C=1000, max_iter=700, penalty=l2, solver=saga; total time=   1.9s
# [CV 5/5] END ..C=1000, max_iter=700, penalty=l2, solver=saga; total time=   1.9s
# Mean Accuracy: 0.905
# Config: {'C': 1, 'max_iter': 400, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
final_model = LR_search.best_estimator_

# %%
final_model
# Out:
# LogisticRegression(C=1, max_iter=400, penalty='l1', solver='liblinear')

# %%
class_ = final_model.predict(X_train)
pred = final_model.predict_proba(X_train)[:,1]

# determine roc_auc score and accuracy
print('train roc-auc: {}'.format(roc_auc_score(y_train, pred)))
print('train accuracy: {}'.format(accuracy_score(y_train, class_)))
print()

# make predictions for test set
class_ = final_model.predict(X_test)
pred = final_model.predict_proba(X_test)[:,1]
print(confusion_matrix(y_test, class_))
print(classification_report(y_test, class_))

# determine roc_auc score and accuracy
print('test roc-auc: {}'.format(roc_auc_score(y_test, pred)))
print('test accuracy: {}'.format(accuracy_score(y_test, class_)))
print()
# Out:
# train roc-auc: 0.9261056551044665
# train accuracy: 0.9066781878780398
#
# [[1650   67]
#  [ 125  184]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      1717
#            1       0.73      0.60      0.66       309
#
#     accuracy                           0.91      2026
#    macro avg       0.83      0.78      0.80      2026
# weighted avg       0.90      0.91      0.90      2026
#
# test roc-auc: 0.924292200779187
# test accuracy: 0.9052319842053307

# %% [markdown]
# ## Procédure d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def model_evaluation(model):
    
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))
    
    N, train_score, val_score = learning_curve(model, X_train, y_train,
                                              cv=4, scoring='f1',
                                               train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %% [markdown]
# ## Mise en place du modèle

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler

# %%
pre_processor = make_pipeline(SelectKBest(f_classif, k=10))

# %%
RandomForest = make_pipeline(pre_processor, RandomForestClassifier(random_state=0))
AdaBoost = make_pipeline(pre_processor, AdaBoostClassifier(random_state=0))
GradientBoost = make_pipeline(pre_processor,GradientBoostingClassifier(random_state = 0))
NaiveBayes = make_pipeline(pre_processor, GaussianNB ())
SVM = make_pipeline(pre_processor, StandardScaler(), SVC(random_state=0))
KNN = make_pipeline(pre_processor, StandardScaler(), KNeighborsClassifier())

# %%
models_dict = {'RandomForest': RandomForest,
                  'AdaBoost' : AdaBoost,
                  'SVM': SVM,
                  'KNN': KNN,
                  'GBT': GradientBoost,
                  'GNB': NaiveBayes
                 }

# %%
for name, model in models_dict.items():
    print(name)
    model_evaluation(model)
# Out:
# RandomForest
# [[1689   28]
#  [  62  247]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      1717
#            1       0.90      0.80      0.85       309
#
#     accuracy                           0.96      2026
#    macro avg       0.93      0.89      0.91      2026
# weighted avg       0.95      0.96      0.95      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=0))])
# AdaBoost
# [[1676   41]
#  [  54  255]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1717
#            1       0.86      0.83      0.84       309
#
#     accuracy                           0.95      2026
#    macro avg       0.92      0.90      0.91      2026
# weighted avg       0.95      0.95      0.95      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('adaboostclassifier', AdaBoostClassifier(random_state=0))])
# SVM
# [[1660   57]
#  [  92  217]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      1717
#            1       0.79      0.70      0.74       309
#
#     accuracy                           0.93      2026
#    macro avg       0.87      0.83      0.85      2026
# weighted avg       0.92      0.93      0.92      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('standardscaler', StandardScaler()),
#                 ('svc', SVC(random_state=0))])
# KNN
# [[1675   42]
#  [ 132  177]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1717
#            1       0.81      0.57      0.67       309
#
#     accuracy                           0.91      2026
#    macro avg       0.87      0.77      0.81      2026
# weighted avg       0.91      0.91      0.91      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier', KNeighborsClassifier())])
# GBT
# [[1691   26]
#  [  52  257]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1717
#            1       0.91      0.83      0.87       309
#
#     accuracy                           0.96      2026
#    macro avg       0.94      0.91      0.92      2026
# weighted avg       0.96      0.96      0.96      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('gradientboostingclassifier',
#                  GradientBoostingClassifier(random_state=0))])
# GNB
# [[1623   94]
#  [ 114  195]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1717
#            1       0.67      0.63      0.65       309
#
#     accuracy                           0.90      2026
#    macro avg       0.80      0.79      0.80      2026
# weighted avg       0.89      0.90      0.90      2026
#
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('selectkbest', SelectKBest(k=15))])),
#                 ('gaussiannb', GaussianNB())])
